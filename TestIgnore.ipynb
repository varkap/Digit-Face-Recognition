# %%
# import all of the required libraries
# import the image, and the number
# create the perceptron algorithm to recognize the dgits

# %%
def detectDigit():
    f = open("digitdata/trainingimages", "r")
    digit = ""
    active_line = ""
    for a in f:
        if "#" in a or "+" in a:
            digit = digit + a
    print(digit)
    f.close()

detectDigit()
# Out:
#                 +++++##+
#         +++++######+###+
#        +##########+++++
#         #######+##
#         +++###  ++
#            +#+
#            +#+
#             +#+
#             +##++
#              +###++
#               ++##++
#                 +##+
#                  ###+
#               +++###
#             ++#####+
#           ++######+
#         ++######+
#        +######+
#     ++######+
#     +####++
#                ++#++
#               +#####
#              +######+
#             +#####+##+
#            +######++#+
#           +###++##++#+
#          +###+ +++  ##+
#         ++###+      ##+
#         +##+ +      ###
#        +##+         ###
#        ##+          ###
#       +##+          ##+
#       +##+         +#+
#       +##         +##+
#       +#+       ++#+
#       +##      +##+
#       +##+++++###++
#       +#########+
#       +#######+
#        ++###++
#                     +#+
#     ++              +++
#     ++              +#+
#     #+             +#+
# ...

# %%
f = open("digitdata/trainingimages", "r")
def detectDigitV2():
    digits = ""
    active_line = ""
    sentinel = 0
    for b in range(50):
        a = f.readline()
        if "#" in a or "+" in a:
            digits = digits + a
            sentinel = 1
        if "                            " in a and sentinel == 1:
            break
    return digits

def reverse(s):
    return s[::-1]

def digitImage():
    digits = detectDigitV2()
    return reverse(digits)
    
    
for x in range(3):
    print(digitImage())
# Out:
#                  ++####+
#                +######++
#              +######+
#            +######++
#          +######++
#         +#####++
#         ###+++
#        +###
#         +##+
#         ++##++
#          ++###+
#            ++##+
#              +#+
#               +#+
#               +#+
#           ++  ###+++
#           ##+#######
#      +++++##########+
#     +###+######+++++
#     +##+++++
#
#               ++###++
#              +#######+
#            +#########+
#          ++###+++++##+
#          +##+      ##+
#         +#++       +#+
#       +##+         ##+
#       +#+         +##+
#      +##          +##+
#      ###          +##
#      ###         +##+
#      ###      + +##+
#      +##      +###++
#      +##  +++ +###+
#       +#++##++###+
#       +#++######+
#       +##+#####+
#        +######+
#         #####+
#         ++#++
#
#         +#+
#         +#+
#         +#+
#         +#+
#         +#+
#         +#+
#         +#+
#         +#+
# ...
